# %% [markdown]
# # Import and load dataset

# %%
from ExpandedTM.data_utils import TMDataset
from ExpandedTM.models.TNTM.TNTM_bow import TNTM_bow

dataset = TMDataset()
dataset.fetch_dataset("BBC_News")

# %% [markdown]
# # Train the model
# If embeddings for the model have been created before, they will not be created again for faster computation

# %%
model = TNTM_bow(num_topics=20, enc_lr= 1e-3, dec_lr = 1e-3)
model_output = model.train_model(dataset)
# Out:
# --- loading pre-computed vocabulary embeddings ---
# 2225it [00:04, 485.62it/s]
# c:\users\arik_\documents\dokumente\job_clausthal\topicmodellingpackage\expandedtm\ExpandedTM\models\TNTM\TNTM_bow.py:135: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   mus_init_ten = torch.tensor(mus_init).to(self.device)
# c:\users\arik_\documents\dokumente\job_clausthal\topicmodellingpackage\expandedtm\ExpandedTM\models\TNTM\TNTM_bow.py:136: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   L_lower_init_ten = torch.tensor(L_lower_init).to(self.device)
# c:\users\arik_\documents\dokumente\job_clausthal\topicmodellingpackage\expandedtm\ExpandedTM\models\TNTM\TNTM_bow.py:137: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   log_diag_init_ten = torch.tensor(log_diag_init).to(self.device)
# Epoch nr 0: mean_train_loss = -1527.1380615234375, mean_train_nl = -1532.2447509765625, mean_train_kld = 5.106331825256348, elapsed time: 6.813889980316162
# Epoch nr 0: median_train_loss = -1510.078125, median_train_nl = -1515.19091796875, median_train_kld = 5.059956073760986, elapsed time: 6.813889980316162
# Epoch nr 0: mean_val_loss = -1611.6390380859375, mean_val_nl = -1612.0994873046875, mean_val_kld = 0.4603986144065857
# Epoch nr 0: median_val_loss = -1598.879638671875, median_val_nl = -1599.349365234375, median_val_kld = 0.4517213702201843
# gradient norm: mean: 2078.0372859917256, median: 1506.9569415925826, max: 7448.282408640622
#
#
# Epoch nr 1: mean_train_loss = -1604.5830078125, mean_train_nl = -1605.2734375, mean_train_kld = 0.6907598376274109, elapsed time: 6.128677129745483
# Epoch nr 1: median_train_loss = -1594.46142578125, median_train_nl = -1594.949462890625, median_train_kld = 0.6319404244422913, elapsed time: 6.128677129745483
# Epoch nr 1: mean_val_loss = -1666.420654296875, mean_val_nl = -1667.6749267578125, mean_val_kld = 1.2543530464172363
# Epoch nr 1: median_val_loss = -1643.41552734375, median_val_nl = -1644.7344970703125, median_val_kld = 1.3189239501953125
# gradient norm: mean: 973.651555341108, median: 955.8764393206355, max: 1186.3235585180912
#
#
# Epoch nr 2: mean_train_loss = -1638.5703125, mean_train_nl = -1641.769287109375, mean_train_kld = 3.198984146118164, elapsed time: 7.3507843017578125
# Epoch nr 2: median_train_loss = -1638.202880859375, median_train_nl = -1642.0718994140625, median_train_kld = 2.9141650199890137, elapsed time: 7.3507843017578125
# Epoch nr 2: mean_val_loss = -1710.09814453125, mean_val_nl = -1716.05078125, mean_val_kld = 5.952415943145752
# Epoch nr 2: median_val_loss = -1696.01123046875, median_val_nl = -1702.0130615234375, median_val_kld = 5.734193801879883
# gradient norm: mean: 896.5611726940809, median: 856.3602745765498, max: 1120.8586570512218
#
#
# Epoch nr 3: mean_train_loss = -1656.853271484375, mean_train_nl = -1667.5211181640625, mean_train_kld = 10.667800903320312, elapsed time: 9.101246118545532
# Epoch nr 3: median_train_loss = -1639.2548828125, median_train_nl = -1645.9345703125, median_train_kld = 10.3972806930542, elapsed time: 9.101246118545532
# Epoch nr 3: mean_val_loss = -1716.4638671875, mean_val_nl = -1732.789306640625, mean_val_kld = 16.325407028198242
# Epoch nr 3: median_val_loss = -1704.386962890625, median_val_nl = -1721.034912109375, median_val_kld = 16.446699142456055
# gradient norm: mean: 868.0596208219389, median: 847.819742917012, max: 1172.9782214006154
#
#
# Epoch nr 4: mean_train_loss = -1662.5301513671875, mean_train_nl = -1682.095703125, mean_train_kld = 19.565439224243164, elapsed time: 5.556700229644775
# Epoch nr 4: median_train_loss = -1651.85302734375, median_train_nl = -1671.842041015625, median_train_kld = 20.1925048828125, elapsed time: 5.556700229644775
# Epoch nr 4: mean_val_loss = -1702.760009765625, mean_val_nl = -1724.544677734375, mean_val_kld = 21.78466796875
# Epoch nr 4: median_val_loss = -1679.5086669921875, median_val_nl = -1700.6318359375, median_val_kld = 21.123071670532227
# gradient norm: mean: 919.618200103785, median: 877.7231406146738, max: 1269.852508966883
#
#
# Epoch nr 5: mean_train_loss = -1671.892333984375, mean_train_nl = -1692.242919921875, mean_train_kld = 20.35053825378418, elapsed time: 5.327415704727173
# Epoch nr 5: median_train_loss = -1644.0101318359375, median_train_nl = -1663.295654296875, median_train_kld = 20.197139739990234, elapsed time: 5.327415704727173
# Epoch nr 5: mean_val_loss = -1697.587158203125, mean_val_nl = -1715.838134765625, mean_val_kld = 18.250934600830078
# Epoch nr 5: median_val_loss = -1732.465576171875, median_val_nl = -1751.1165771484375, median_val_kld = 18.651050567626953
# gradient norm: mean: 892.1551993218933, median: 861.7356168621695, max: 1099.613366007476
#
#
# Epoch nr 6: mean_train_loss = -1678.9796142578125, mean_train_nl = -1694.9339599609375, mean_train_kld = 15.954527854919434, elapsed time: 8.072956800460815
# Epoch nr 6: median_train_loss = -1673.8768310546875, median_train_nl = -1688.414306640625, median_train_kld = 15.845707893371582, elapsed time: 8.072956800460815
# Epoch nr 6: mean_val_loss = -1722.438232421875, mean_val_nl = -1735.8743896484375, mean_val_kld = 13.436264038085938
# Epoch nr 6: median_val_loss = -1623.10205078125, median_val_nl = -1635.752685546875, median_val_kld = 12.650572776794434
# gradient norm: mean: 914.4031280173787, median: 900.2845875998925, max: 1147.5995668699202
#
#
# Epoch nr 7: mean_train_loss = -1685.0, mean_train_nl = -1696.5765380859375, mean_train_kld = 11.576475143432617, elapsed time: 4.7853968143463135
# Epoch nr 7: median_train_loss = -1688.9501953125, median_train_nl = -1700.783203125, median_train_kld = 11.545948028564453, elapsed time: 4.7853968143463135
# Epoch nr 7: mean_val_loss = -1706.4749755859375, mean_val_nl = -1716.818603515625, mean_val_kld = 10.34355354309082
# Epoch nr 7: median_val_loss = -1715.276123046875, median_val_nl = -1725.822509765625, median_val_kld = 10.370616912841797
# gradient norm: mean: 924.7885805025214, median: 927.5805371884292, max: 1047.2274357190356
#
#
# Epoch nr 8: mean_train_loss = -1689.4453125, mean_train_nl = -1699.197021484375, mean_train_kld = 9.751501083374023, elapsed time: 4.761596202850342
# Epoch nr 8: median_train_loss = -1654.2415771484375, median_train_nl = -1664.065673828125, median_train_kld = 9.677963256835938, elapsed time: 4.761596202850342
# Epoch nr 8: mean_val_loss = -1752.1865234375, mean_val_nl = -1762.0750732421875, mean_val_kld = 9.888635635375977
# Epoch nr 8: median_val_loss = -1723.2147216796875, median_val_nl = -1732.933349609375, median_val_kld = 9.721168518066406
# gradient norm: mean: 891.2767986939144, median: 890.6290421808249, max: 1104.1415520382275
#
#
# Epoch nr 9: mean_train_loss = -1694.9986572265625, mean_train_nl = -1704.6463623046875, mean_train_kld = 9.64798641204834, elapsed time: 7.898654460906982
# Epoch nr 9: median_train_loss = -1704.5057373046875, median_train_nl = -1714.0726318359375, median_train_kld = 9.602376937866211, elapsed time: 7.898654460906982
# Epoch nr 9: mean_val_loss = -1727.8349609375, mean_val_nl = -1738.1102294921875, mean_val_kld = 10.275345802307129
# Epoch nr 9: median_val_loss = -1706.7125244140625, median_val_nl = -1716.792236328125, median_val_kld = 10.148097038269043
# gradient norm: mean: 923.4201309708403, median: 908.9962091940613, max: 1154.088025254053
#
#
# Epoch nr 10: mean_train_loss = -1697.8785400390625, mean_train_nl = -1708.2484130859375, mean_train_kld = 10.370026588439941, elapsed time: 6.943440198898315
# Epoch nr 10: median_train_loss = -1703.4697265625, median_train_nl = -1714.376708984375, median_train_kld = 10.456610679626465, elapsed time: 6.943440198898315
# Epoch nr 10: mean_val_loss = -1717.2294921875, mean_val_nl = -1728.310791015625, mean_val_kld = 11.081193923950195
# Epoch nr 10: median_val_loss = -1744.80322265625, median_val_nl = -1755.872314453125, median_val_kld = 11.069089889526367
# gradient norm: mean: 939.0555472530597, median: 933.1125259577827, max: 1068.1548086501325
#
#
# Epoch nr 11: mean_train_loss = -1702.0333251953125, mean_train_nl = -1713.614501953125, mean_train_kld = 11.581147193908691, elapsed time: 9.2634756565094
# Epoch nr 11: median_train_loss = -1667.373291015625, median_train_nl = -1678.698974609375, median_train_kld = 11.593706130981445, elapsed time: 9.2634756565094
# Epoch nr 11: mean_val_loss = -1725.6478271484375, mean_val_nl = -1738.175048828125, mean_val_kld = 12.527251243591309
# Epoch nr 11: median_val_loss = -1712.4598388671875, median_val_nl = -1724.834716796875, median_val_kld = 12.392217636108398
# gradient norm: mean: 943.8178422415986, median: 933.3485244997377, max: 1139.0995364652192
#
#
# Epoch nr 12: mean_train_loss = -1704.0316162109375, mean_train_nl = -1717.0638427734375, mean_train_kld = 13.032259941101074, elapsed time: 9.344545841217041
# Epoch nr 12: median_train_loss = -1708.14404296875, median_train_nl = -1721.39794921875, median_train_kld = 13.199075698852539, elapsed time: 9.344545841217041
# Epoch nr 12: mean_val_loss = -1760.0731201171875, mean_val_nl = -1774.1910400390625, mean_val_kld = 14.117935180664062
# Epoch nr 12: median_val_loss = -1735.8155517578125, median_val_nl = -1749.646484375, median_val_kld = 13.830888748168945
# gradient norm: mean: 999.4806106517048, median: 1001.6030840723522, max: 1080.506571570234
#
#
# Epoch nr 13: mean_train_loss = -1707.7640380859375, mean_train_nl = -1721.970947265625, mean_train_kld = 14.206865310668945, elapsed time: 7.505481719970703
# Epoch nr 13: median_train_loss = -1727.5670166015625, median_train_nl = -1741.699951171875, median_train_kld = 14.141130447387695, elapsed time: 7.505481719970703
# Epoch nr 13: mean_val_loss = -1731.641845703125, mean_val_nl = -1746.4261474609375, mean_val_kld = 14.78431510925293
# Epoch nr 13: median_val_loss = -1715.5750732421875, median_val_nl = -1730.085693359375, median_val_kld = 14.611137390136719
# gradient norm: mean: 996.887812860223, median: 999.3955351967548, max: 1183.888511207234
#
#
# Epoch nr 14: mean_train_loss = -1710.2335205078125, mean_train_nl = -1725.0064697265625, mean_train_kld = 14.772881507873535, elapsed time: 6.889967679977417
# Epoch nr 14: median_train_loss = -1723.0445556640625, median_train_nl = -1737.8470458984375, median_train_kld = 14.729721069335938, elapsed time: 6.889967679977417
# Epoch nr 14: mean_val_loss = -1754.394287109375, mean_val_nl = -1769.442138671875, mean_val_kld = 15.047796249389648
# Epoch nr 14: median_val_loss = -1757.684814453125, median_val_nl = -1772.76708984375, median_val_kld = 15.082294464111328
# gradient norm: mean: 965.5313359680832, median: 964.2464599923926, max: 1107.2693180590452
#
#
# Epoch nr 15: mean_train_loss = -1713.6805419921875, mean_train_nl = -1728.4208984375, mean_train_kld = 14.740654945373535, elapsed time: 6.304333925247192
# Epoch nr 15: median_train_loss = -1698.1427001953125, median_train_nl = -1712.886474609375, median_train_kld = 14.669637680053711, elapsed time: 6.304333925247192
# Epoch nr 15: mean_val_loss = -1728.632080078125, mean_val_nl = -1743.15185546875, mean_val_kld = 14.519821166992188
# Epoch nr 15: median_val_loss = -1748.529296875, median_val_nl = -1763.1690673828125, median_val_kld = 14.639843940734863
# gradient norm: mean: 968.1410537311539, median: 945.5645845537401, max: 1128.9906167267368
#
#
# Epoch nr 16: mean_train_loss = -1716.6478271484375, mean_train_nl = -1731.0255126953125, mean_train_kld = 14.377939224243164, elapsed time: 6.276323080062866
# Epoch nr 16: median_train_loss = -1730.258056640625, median_train_nl = -1744.898681640625, median_train_kld = 14.456521034240723, elapsed time: 6.276323080062866
# Epoch nr 16: mean_val_loss = -1761.020263671875, mean_val_nl = -1775.2845458984375, mean_val_kld = 14.264474868774414
# Epoch nr 16: median_val_loss = -1721.044677734375, median_val_nl = -1735.153076171875, median_val_kld = 14.108392715454102
# gradient norm: mean: 980.9736948481452, median: 967.9853769568001, max: 1121.8358411218687
#
#
# Epoch nr 17: mean_train_loss = -1719.7637939453125, mean_train_nl = -1733.663818359375, mean_train_kld = 13.89991569519043, elapsed time: 5.088382720947266
# Epoch nr 17: median_train_loss = -1724.4654541015625, median_train_nl = -1738.4241943359375, median_train_kld = 13.94552993774414, elapsed time: 5.088382720947266
# Epoch nr 17: mean_val_loss = -1732.1595458984375, mean_val_nl = -1745.722412109375, mean_val_kld = 13.562715530395508
# Epoch nr 17: median_val_loss = -1750.188720703125, median_val_nl = -1764.106689453125, median_val_kld = 13.837411880493164
# gradient norm: mean: 1018.1978483205347, median: 1001.7932912820477, max: 1336.1220824872871
#
#
# Epoch nr 18: mean_train_loss = -1721.260009765625, mean_train_nl = -1734.634521484375, mean_train_kld = 13.374518394470215, elapsed time: 6.105655193328857
# Epoch nr 18: median_train_loss = -1733.8944091796875, median_train_nl = -1747.342041015625, median_train_kld = 13.398994445800781, elapsed time: 6.105655193328857
# Epoch nr 18: mean_val_loss = -1737.850341796875, mean_val_nl = -1750.9014892578125, mean_val_kld = 13.051002502441406
# Epoch nr 18: median_val_loss = -1757.62939453125, median_val_nl = -1771.1158447265625, median_val_kld = 13.055669784545898
# gradient norm: mean: 1028.762984082655, median: 1016.39376523894, max: 1219.6192406420448
#
#
# Epoch nr 19: mean_train_loss = -1723.622802734375, mean_train_nl = -1736.5213623046875, mean_train_kld = 12.898665428161621, elapsed time: 8.246549129486084
# Epoch nr 19: median_train_loss = -1719.0419921875, median_train_nl = -1732.1890869140625, median_train_kld = 12.767423629760742, elapsed time: 8.246549129486084
# Epoch nr 19: mean_val_loss = -1770.2947998046875, mean_val_nl = -1783.0872802734375, mean_val_kld = 12.792431831359863
# Epoch nr 19: median_val_loss = -1783.0230712890625, median_val_nl = -1795.649658203125, median_val_kld = 12.626466751098633
# gradient norm: mean: 1034.4000161782621, median: 1039.130857595293, max: 1138.4504793990566
#
#
# Epoch nr 20: mean_train_loss = -1725.208740234375, mean_train_nl = -1737.7965087890625, mean_train_kld = 12.587956428527832, elapsed time: 5.735572338104248
# Epoch nr 20: median_train_loss = -1742.309814453125, median_train_nl = -1755.2764892578125, median_train_kld = 12.700798034667969, elapsed time: 5.735572338104248
# Epoch nr 20: mean_val_loss = -1746.3424072265625, mean_val_nl = -1758.7138671875, mean_val_kld = 12.371511459350586
# Epoch nr 20: median_val_loss = -1774.986328125, median_val_nl = -1787.52392578125, median_val_kld = 12.537315368652344
# gradient norm: mean: 1048.31463337372, median: 1049.7682745494149, max: 1148.764221340803
#
#
# Epoch nr 21: mean_train_loss = -1727.8419189453125, mean_train_nl = -1740.3951416015625, mean_train_kld = 12.55296802520752, elapsed time: 6.960952997207642
# Epoch nr 21: median_train_loss = -1729.9495849609375, median_train_nl = -1742.525634765625, median_train_kld = 12.66046142578125, elapsed time: 6.960952997207642
# Epoch nr 21: mean_val_loss = -1782.1993408203125, mean_val_nl = -1794.853759765625, mean_val_kld = 12.654401779174805
# Epoch nr 21: median_val_loss = -1738.877685546875, median_val_nl = -1751.300048828125, median_val_kld = 12.50709342956543
# gradient norm: mean: 1071.9578201862898, median: 1077.0363741704373, max: 1209.6342874048687
#
#
# Epoch nr 22: mean_train_loss = -1729.0400390625, mean_train_nl = -1741.7249755859375, mean_train_kld = 12.685026168823242, elapsed time: 5.949028730392456
# Epoch nr 22: median_train_loss = -1733.50927734375, median_train_nl = -1746.399658203125, median_train_kld = 12.72281265258789, elapsed time: 5.949028730392456
# Epoch nr 22: mean_val_loss = -1786.405517578125, mean_val_nl = -1799.1522216796875, mean_val_kld = 12.746829986572266
# Epoch nr 22: median_val_loss = -1694.505615234375, median_val_nl = -1706.936767578125, median_val_kld = 12.43112564086914
# gradient norm: mean: 1071.3243040784319, median: 1073.291343678472, max: 1187.9730074716574
#
#
# Early stopping because the median validation loss has not decreased since the last 10 epochs
